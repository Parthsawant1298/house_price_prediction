# %% [markdown]
# <a href="https://colab.research.google.com/github/Parthsawant1298/house_price_prediction/blob/main/house%20price%20prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('House Price India.csv')

# %%
dataset.head(5)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# 4  6762813105  42491                   3                 2.50         2600
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      4000               1.5                   0                0
# 1      9480               1.5                   0                0
# 2     42998               2.0                   0                0
# 3      4500               1.5                   0                0
# 4      4750               1.0                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
dataset.drop(['id'],axis=1,inplace=True)

# %%
dataset.drop(['Date'],axis=1,inplace=True)

# %%
dataset.drop(['Renovation Year','Postal Code'],axis=1,inplace=True)

# %%
dataset.drop(['lot_area_renov','living_area_renov','lot area','number of bathrooms'],axis=1,inplace=True)

# %%
dataset.head(5)
# Out:
#    number of bedrooms  living area  number of floors  waterfront present  \
# 0                   4         2920               1.5                   0
# 1                   5         2910               1.5                   0
# 2                   4         3310               2.0                   0
# 3                   3         2710               1.5                   0
# 4                   3         2600               1.0                   0
#
#    number of views  condition of the house  grade of the house  \
# 0                0                       5                   8
# 1                0                       3                   8
# 2                0                       3                   9
# 3                0                       4                   8
# 4                0                       4                   9
#
#    Area of the house(excluding basement)  Area of the basement  Built Year  \
# ...

# %%
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
print(x)
# Out:
# [[ 4.00000e+00  2.92000e+03  1.50000e+00 ... -1.14470e+02  2.00000e+00
#    5.10000e+01]
#  [ 5.00000e+00  2.91000e+03  1.50000e+00 ... -1.14468e+02  1.00000e+00
#    5.30000e+01]
#  [ 4.00000e+00  3.31000e+03  2.00000e+00 ... -1.14321e+02  3.00000e+00
#    7.60000e+01]
#  ...
#  [ 2.00000e+00  1.07000e+03  1.00000e+00 ... -1.14507e+02  2.00000e+00
#    6.40000e+01]
#  [ 4.00000e+00  1.03000e+03  1.00000e+00 ... -1.14411e+02  3.00000e+00
#    5.40000e+01]
#  [ 3.00000e+00  9.00000e+02  1.00000e+00 ... -1.14552e+02  2.00000e+00
#    5.50000e+01]]

# %%
print(y)
# Out:
# [1400000 1200000  838000 ...  209000  205000  146000]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=50,random_state=0)
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=0)

# %%
print('prediction:',regressor.predict(sc.fit_transform([[4 ,2920,  1.5  ,0,  0   ,5,  8,   1910 ,1010, 1909, 52.8878, -114.470, 2, 51]]))[0])
# Out:
# prediction: 701309.2

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8757180160288587
